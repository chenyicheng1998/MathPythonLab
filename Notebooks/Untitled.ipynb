# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(-100,100.01,0.01)
y = x**2+x-11
plt.plot(x, y)
plt.xlim(2.8, 2.9)
plt.ylim(-1, 1)
plt.grid(True)
plt.show()
# The value of the second root with two decimals accuracy
x2 = 3
